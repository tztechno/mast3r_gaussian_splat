# %% [markdown]
# ## **CLI MASt3R 3D Reconstruction for Gaussian Splat**

# %%
# !rm -rf /kaggle/working/*

# %%
import os
os.chdir('/kaggle/working')

# %%
# !git clone https://github.com/tztechno/mast3r_gaussiansplat.git
# Out:
# Cloning into 'mast3r_gaussiansplat'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 379 (delta 76), reused 0 (delta 0), pack-reused 203 (from 1)
# Receiving objects: 100% (379/379), 449.91 KiB | 4.41 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
import os
os.chdir('/kaggle/working/mast3r_gaussiansplat')

# %%
# !python -m pipeline.mainpipeline
# Out:
# 2026-01-27 11:59:48.789311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769515188.812742    2495 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769515188.819808    2495 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769515188.838466    2495 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ![](https://huggingface.co/datasets/stpete2/npy/resolve/main/bike_dino_mast3r_ps1.png)

# %% [markdown]
# # **3D Gaussian Splat View**
#
# [https://splat-three.vercel.app/?url=bike_mast3r_ps1.splat](https://splat-three.vercel.app/?url=bike_mast3r_ps1.splat#[0.61,-0.35,0.71,0,0.26,0.93,0.24,0,-0.76,0.04,0.65,0,0.53,0.08,0.9,1])
